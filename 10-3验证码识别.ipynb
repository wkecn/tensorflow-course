# %%
import os
import tensorflow as tf 
from PIL import Image
from nets import nets_factory
import numpy as np
'''
@author :wangkechn
https://github.com/wangkechn
'''

# %%
# 不同字符数量
CHAR_SET_LEN = 10
# 图片高度
IMAGE_HEIGHT = 60 
# 图片宽度
IMAGE_WIDTH = 160  
# 批次
BATCH_SIZE = 25
# tfrecord文件存放路径
TFRECORD_FILE = r"C:\Users\wangkechn\Workspace-tensorflow\tensorflow-course\captcha\train.tfrecords"

# placeholder
x = tf.placeholder(tf.float32, [None, 224, 224])  
y0 = tf.placeholder(tf.float32, [None]) 
y1 = tf.placeholder(tf.float32, [None]) 
y2 = tf.placeholder(tf.float32, [None]) 
y3 = tf.placeholder(tf.float32, [None])

# 学习率
lr = tf.Variable(0.003, dtype=tf.float32)

# 从tfrecord读出数据
def read_and_decode(filename):
    # 根据文件名生成一个队列
    filename_queue = tf.train.string_input_producer([filename])
    reader = tf.TFRecordReader()
    # 返回文件名和文件
    _, serialized_example = reader.read(filename_queue)   
    features = tf.parse_single_example(serialized_example,
                                       features={
                                           'image' : tf.FixedLenFeature([], tf.string),
                                           'label0': tf.FixedLenFeature([], tf.int64),
                                           'label1': tf.FixedLenFeature([], tf.int64),
                                           'label2': tf.FixedLenFeature([], tf.int64),
                                           'label3': tf.FixedLenFeature([], tf.int64),
                                       })
    # 获取图片数据
    image = tf.decode_raw(features['image'], tf.uint8)
    # tf.train.shuffle_batch必须确定shape
    image = tf.reshape(image, [224, 224])
    # 图片预处理
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.subtract(image, 0.5)
    image = tf.multiply(image, 2.0)
    # 获取label
    label0 = tf.cast(features['label0'], tf.int32)
    label1 = tf.cast(features['label1'], tf.int32)
    label2 = tf.cast(features['label2'], tf.int32)
    label3 = tf.cast(features['label3'], tf.int32)

    return image, label0, label1, label2, label3


# In[3]:

# 获取图片数据和标签
image, label0, label1, label2, label3 = read_and_decode(TFRECORD_FILE)

#使用shuffle_batch可以随机打乱
image_batch, label_batch0, label_batch1, label_batch2, label_batch3 = tf.train.shuffle_batch(
        [image, label0, label1, label2, label3], batch_size = BATCH_SIZE,
        capacity = 50000, min_after_dequeue=10000, num_threads=1)

#定义网络结构
train_network_fn = nets_factory.get_network_fn(
    'alexnet_v2',
    num_classes=CHAR_SET_LEN,
    weight_decay=0.0005,
    is_training=True)
 
    
with tf.Session() as sess:
    # inputs: a tensor of size [batch_size, height, width, channels]
    X = tf.reshape(x, [BATCH_SIZE, 224, 224, 1])
    # 数据输入网络得到输出值
    logits0,logits1,logits2,logits3,end_points = train_network_fn(X)
    
    # 把标签转成one_hot的形式
    one_hot_labels0 = tf.one_hot(indices=tf.cast(y0, tf.int32), depth=CHAR_SET_LEN)
    one_hot_labels1 = tf.one_hot(indices=tf.cast(y1, tf.int32), depth=CHAR_SET_LEN)
    one_hot_labels2 = tf.one_hot(indices=tf.cast(y2, tf.int32), depth=CHAR_SET_LEN)
    one_hot_labels3 = tf.one_hot(indices=tf.cast(y3, tf.int32), depth=CHAR_SET_LEN)
    
    # 计算loss
    loss0 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits0,labels=one_hot_labels0)) 
    loss1 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits1,labels=one_hot_labels1)) 
    loss2 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits2,labels=one_hot_labels2)) 
    loss3 = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits3,labels=one_hot_labels3)) 
    # 计算总的loss
    total_loss = (loss0+loss1+loss2+loss3)/4.0
    # 优化total_loss
    optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(total_loss) 
    
    # 计算准确率
    correct_prediction0 = tf.equal(tf.argmax(one_hot_labels0,1),tf.argmax(logits0,1))
    accuracy0 = tf.reduce_mean(tf.cast(correct_prediction0,tf.float32))
    
    correct_prediction1 = tf.equal(tf.argmax(one_hot_labels1,1),tf.argmax(logits1,1))
    accuracy1 = tf.reduce_mean(tf.cast(correct_prediction1,tf.float32))
    
    correct_prediction2 = tf.equal(tf.argmax(one_hot_labels2,1),tf.argmax(logits2,1))
    accuracy2 = tf.reduce_mean(tf.cast(correct_prediction2,tf.float32))
    
    correct_prediction3 = tf.equal(tf.argmax(one_hot_labels3,1),tf.argmax(logits3,1))
    accuracy3 = tf.reduce_mean(tf.cast(correct_prediction3,tf.float32)) 
    
    # 用于保存模型
    saver = tf.train.Saver()
    # 初始化
    sess.run(tf.global_variables_initializer())
    
    # 创建一个协调器，管理线程
    coord = tf.train.Coordinator()
    # 启动QueueRunner, 此时文件名队列已经进队
    threads = tf.train.start_queue_runners(sess=sess, coord=coord)

    for i in range(6001):
        # 获取一个批次的数据和标签
        b_image, b_label0, b_label1 ,b_label2 ,b_label3 = sess.run([image_batch, label_batch0, label_batch1, label_batch2, label_batch3])
        # 优化模型
        sess.run(optimizer, feed_dict={x: b_image, y0:b_label0, y1: b_label1, y2: b_label2, y3: b_label3})  

        # 每迭代20次计算一次loss和准确率  
        if i % 20 == 0:  
            # 每迭代2000次降低一次学习率
            if i%2000 == 0:
                sess.run(tf.assign(lr, lr/3))
            acc0,acc1,acc2,acc3,loss_ = sess.run([accuracy0,accuracy1,accuracy2,accuracy3,total_loss],feed_dict={x: b_image,
                                                                                                                y0: b_label0,
                                                                                                                y1: b_label1,
                                                                                                                y2: b_label2,
                                                                                                                y3: b_label3})      
            learning_rate = sess.run(lr)
            print ("Iter:%d  Loss:%.3f  Accuracy:%.2f,%.2f,%.2f,%.2f  Learning_rate:%.4f" % (i,loss_,acc0,acc1,acc2,acc3,learning_rate))
             
            # 保存模型
            # if acc0 > 0.90 and acc1 > 0.90 and acc2 > 0.90 and acc3 > 0.90: 
            if i==6000:
                saver.save(sess, "./captcha/models/crack_captcha.model", global_step=i)  
                break 
                
    # 通知其他线程关闭
    coord.request_stop()
    # 其他所有线程关闭之后，这一函数才能返回
    coord.join(threads)
# Out:
# WARNING:tensorflow:From <ipython-input-2-78b6b6b32842>:85: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# Iter:0  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:20  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:40  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:60  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:80  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:100  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:120  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:140  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:160  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:180  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:200  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:220  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:240  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:260  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:280  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:300  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:320  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:340  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:360  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:380  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:400  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:420  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:440  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:460  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:480  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:500  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:520  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:540  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:560  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:580  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:600  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:620  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:640  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:660  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:680  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:700  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:720  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:740  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:760  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:780  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:800  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:820  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:840  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:860  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:880  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:900  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:920  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:940  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:960  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:980  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1000  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1020  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1040  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1060  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1080  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1100  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1120  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1140  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1160  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1180  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1200  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1220  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1240  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1260  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1280  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1300  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1320  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1340  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1360  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1380  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1400  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1420  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1440  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1460  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1480  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1500  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1520  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1540  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1560  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1580  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1600  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1620  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1640  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1660  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1680  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1700  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1720  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1740  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1760  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1780  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1800  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1820  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1840  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1860  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1880  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1900  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1920  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1940  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1960  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:1980  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0010
# Iter:2000  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2020  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2040  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2060  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2080  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2100  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2120  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2140  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2160  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2180  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2200  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2220  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2240  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2260  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2280  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2300  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2320  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2340  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2360  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2380  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2400  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2420  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2440  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2460  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2480  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2500  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2520  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2540  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2560  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2580  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2600  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2620  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2640  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2660  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2680  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2700  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2720  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2740  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2760  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2780  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2800  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2820  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2840  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2860  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2880  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2900  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2920  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2940  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2960  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:2980  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3000  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3020  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3040  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3060  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3080  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3100  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3120  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3140  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3160  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3180  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3200  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3220  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3240  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3260  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3280  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3300  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3320  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3340  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3360  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3380  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3400  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3420  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3440  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3460  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3480  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3500  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3520  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3540  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3560  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3580  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3600  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3620  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3640  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3660  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3680  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3700  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3720  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3740  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3760  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3780  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3800  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3820  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3840  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3860  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3880  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3900  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3920  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3940  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3960  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:3980  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0003
# Iter:4000  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4020  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4040  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4060  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4080  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4100  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4120  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4140  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4160  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4180  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4200  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4220  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4240  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4260  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4280  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4300  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4320  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4340  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4360  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4380  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4400  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4420  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4440  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4460  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4480  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4500  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4520  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4540  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4560  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4580  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4600  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4620  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4640  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4660  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4680  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4700  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4720  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4740  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4760  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4780  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4800  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4820  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4840  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4860  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4880  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4900  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4920  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4940  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4960  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:4980  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5000  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5020  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5040  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5060  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5080  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5100  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5120  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5140  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5160  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5180  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5200  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5220  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5240  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5260  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5280  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5300  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5320  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5340  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5360  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5380  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5400  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5420  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5440  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5460  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5480  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5500  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5520  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5540  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5560  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5580  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5600  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5620  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5640  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5660  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5680  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5700  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5720  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5740  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5760  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5780  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5800  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5820  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5840  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5860  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5880  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5900  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5920  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5940  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5960  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:5980  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0001
# Iter:6000  Loss:0.000  Accuracy:1.00,1.00,1.00,1.00  Learning_rate:0.0000
